# %% [markdown]
# # 시계열 수치입력 수치 예측 모델(상태유지 스택 순환신경망)
# - 시계열 수치를 입력해서 다음 수치를 예측하는 모델
# - 각 모델에 코사인(cosine) 데이터를 학습시킨 후, 처음 일부 데이터를 알려주면 이후 코사인 형태의 데이터 예측을 얼마나 잘 하는 지 테스트

# %% [markdown]
# ### 사용할 패키지 불러오기

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 사용자 히스토리 클래스

# %%
class CustomHistory(Callback):
        def init(self):
            self.train_loss = []
            self.val_loss = []
            
        def on_epoch_end(self, batch, logs={}):
            self.train_loss.append(logs.get('loss'))
            self.val_loss.append(logs.get('val_loss'))

# %% [markdown]
# #### 데이터셋 만들기
# - 생성한 코사인 데이터를 모델에 학습시키기 위해서는 데이터와 라벨로 구성된 데이터셋으로 만들기
# - 이전 수치들을 입력하여 다음 수치를 예측하는 문제
#     - 데이터는 이전 수치
#     - 라벨은 다음 수치
# - 다른 예제들과는 달리 데이터와 라벨이 모두 같은 속성
# - create_dataset() 함수는 시계열 수치를 입력받아 데이터셋을 생성
#     - look_back 인자는 얼마만큼의 이전 수치를 데이터로 만들것인가를 결정

# %%
def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 40

# %% [markdown]
# ### 1 데이터 셋 생성하기
# * 시간의 흐름에 따라 진폭이 -1.0에서 1.0사이로 변하는 1,600개의 실수값을 생성

# %%
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# %%
# %matplotlib inline

plot_x = np.arange(1600)
plot_y = signal_data
plt.plot(plot_x, plot_y)
plt.show()

# %% [markdown]
# #### 데이터 전처리

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# %% [markdown]
# #### 데이터 분리

# %%
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# %% [markdown]
# #### 데이터셋 생성

# %%
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# %% [markdown]
# #### 데이터셋 전처리

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# ### 2 모델 구성하기
# - LSTM
#     - Long-Short Term Memory unit의 약자로 순환 신경망 레이어 중 하나
# - tanh
#     - LSTM의 출력 활성화 함수로 사용
# - stateful = True
#     - 상태유지가 가능한 순환신경망 모델 구성
#     - 한 배치에서 학습된 상태가 다음 배치 학습 시에 전달되는 방식

# %%
model = Sequential()

for i in range(2):
    model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True, return_sequences=True))
    model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (1, 40, 32)               4352
# _________________________________________________________________
# dropout (Dropout)            (1, 40, 32)               0
# _________________________________________________________________
# lstm_1 (LSTM)                (1, 40, 32)               8320
# _________________________________________________________________
# dropout_1 (Dropout)          (1, 40, 32)               0
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 32)                   8320
# _________________________________________________________________
# dropout_2 (Dropout)          (1, 32)                   0
# _________________________________________________________________
# dense (Dense)                (1, 1)                    33
# =================================================================
# Total params: 21,025
# Trainable params: 21,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. 모델 학습과정 설정하기

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ### 4. 모델 학습시키기

# %%
custom_hist = CustomHistory()
custom_hist.init()

for i in range(200):
    model.fit(x_train, y_train, epochs=1, batch_size=1, shuffle=False, validation_data=(x_val, y_val), callbacks=[custom_hist])
    model.reset_states()
# Out:
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0289 - val_loss: 0.0247
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1232 - val_loss: 0.1316
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1357 - val_loss: 0.1317
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1447 - val_loss: 0.1288
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1399 - val_loss: 0.1275
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1378 - val_loss: 0.1258
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1330 - val_loss: 0.1248
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1398 - val_loss: 0.1271
# 760/760 [==============================] - 5s 6ms/step - loss: 0.1305 - val_loss: 0.1071
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0842 - val_loss: 0.0195
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0216 - val_loss: 0.0123
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0119 - val_loss: 0.0063
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0107 - val_loss: 0.0309
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0115 - val_loss: 0.0165
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0107 - val_loss: 0.0185
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0099 - val_loss: 0.0166
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0089 - val_loss: 0.0224
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0107 - val_loss: 0.0136
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0086 - val_loss: 0.0219
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0088 - val_loss: 0.0063
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0106 - val_loss: 0.1658
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0339 - val_loss: 0.0109
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0069 - val_loss: 0.0084
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0109 - val_loss: 0.0027
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0070 - val_loss: 0.0154
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0079 - val_loss: 0.0075
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0095 - val_loss: 0.0077
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0075 - val_loss: 0.0022
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0060 - val_loss: 0.0071
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0076 - val_loss: 0.0128
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0059 - val_loss: 0.0027
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0059 - val_loss: 0.0099
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0107 - val_loss: 0.0041
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0043 - val_loss: 3.4439e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0041 - val_loss: 0.0035
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0048 - val_loss: 0.0054
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0056 - val_loss: 0.0194
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0087 - val_loss: 0.0028
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0071 - val_loss: 0.0054
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0070 - val_loss: 0.0033
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0050 - val_loss: 0.0022
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0036 - val_loss: 0.0017
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0042 - val_loss: 0.0020
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0046 - val_loss: 0.0026
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0041 - val_loss: 0.0012
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0047 - val_loss: 0.0033
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0052 - val_loss: 0.0018
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0044 - val_loss: 0.0020
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0035 - val_loss: 0.0041
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0048 - val_loss: 0.0038
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0045 - val_loss: 0.0044
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0042 - val_loss: 4.2614e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0039 - val_loss: 0.0023
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0035 - val_loss: 0.0106
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0034 - val_loss: 0.0022
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0040 - val_loss: 0.0011
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0036 - val_loss: 0.0014
# 760/760 [==============================] - 5s 6ms/step - loss: 0.
-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0026 - val_loss: 7.5156e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0025 - val_loss: 4.2200e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0025 - val_loss: 3.2140e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0027 - val_loss: 3.0644e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0026 - val_loss: 3.5988e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0021 - val_loss: 8.0268e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0024 - val_loss: 0.0012
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 0.0013
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0025 - val_loss: 0.0011
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 0.0012
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 9.4620e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 0.0013
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0025 - val_loss: 4.6054e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 0.0014
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 4.8876e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 0.0012
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0025 - val_loss: 8.0440e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0020 - val_loss: 9.9413e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0025 - val_loss: 9.3995e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0025 - val_loss: 3.1913e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 0.0013
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 8.2066e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 4.4450e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 4.9413e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 6.2192e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0027 - val_loss: 0.0016
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 1.6007e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0027 - val_loss: 2.1945e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 0.0012
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 4.7198e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0022 - val_loss: 4.2773e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 6.2742e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 5.1809e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0022 - val_loss: 3.3554e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0021 - val_loss: 0.0014
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0022 - val_loss: 3.2879e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0021 - val_loss: 6.0656e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 6.0874e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 0.0022
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 3.9227e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0022 - val_loss: 9.2410e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0027 - val_loss: 0.0013
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 0.0016
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 0.0010
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0026 - val_loss: 5.0006e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 0.0013
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 9.6840e-05
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 3.3608e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 0.0017
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0023 - val_loss: 7.0206e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0021 - val_loss: 0.0011
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0022 - val_loss: 2.8835e-04
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0024 - val_loss: 0.0014
# 760/760 [==============================] - 5s 6ms/step - loss: 0.0027 - val_loss: 4.8422e-04

# %% [markdown]
# ### 5. 학습과정 살펴보기

# %%
plt.plot(custom_hist.train_loss)
plt.plot(custom_hist.val_loss)
plt.ylim(0.0, 0.10)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ### 6. 모델 평가하기

# %%
trainScore = model.evaluate(x_train, y_train, batch_size=1, verbose=0)
model.reset_states()
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val,  batch_size=1, verbose=0)
model.reset_states()
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test,  batch_size=1, verbose=1)
model.reset_states()
print('Test Score: ', testScore)
# Out:
# Train Score:  0.00047312318929471076
# Validataion Score:  0.0004829165118280798
# 360/360 [==============================] - 1s 3ms/step - loss: 4.8292e-04
# Test Score:  0.0004829165118280798

# %% [markdown]
# ### 7. 모델 사용하기

# %%
look_ahead = 250
xhat = x_test[0]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):    
    prediction = model.predict(np.array([xhat]), batch_size=1)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:],prediction])

# %%
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
